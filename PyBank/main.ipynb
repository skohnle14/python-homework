# %%
# Import CSV File and create file path
import csv

# set path of the files
csvpath = ("/Users/samkohnle/Desktop/Assignment2/python-homework/PyBank/budget_data.csv")

# Indexing variables
months = 0
net_profit = 0
month_change = []

# Opening of the CSV File
with open(csvpath, 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    csv_header = next(csvreader)
    
    for row in csvreader:
        print(row)
        date = row[0]
        profit_losses=int(row[1])
# Total number of months
        months+=1
        print(months)
# Net Total of Profit/Losses    
with open(csvpath, 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    csv_header = next(csvreader)
    
    for row in csvreader:
        print(row)
        date = row[0]
        profit_losses=int(row[1])  
        profit_gain = int(row[1])
        net_profit = net_profit + profit_gain
        print(net_profit)
# AVERAGE CHANGES IN PR0FIT/LOSSES OVER ENTIRE PERIOD
def average (numbers):
    total = 0.0
    for number in numbers:
        total += number
    find_average = total/len(numbers)
    return find_average
# Variables for appended Row
total = []
Timeframe = []
month_change = []
# Additional row from append  
for row in csvreader:
        Timeframe.append(row[0])
        total.append(row[1])
        month_change.append(int(row[1]))
# Calculating questions 3,4, and 5
        net_revenue = [j-i for i,j in zip(month_change[:-1], month_change[1:])]
        average_change=f'Average Change: ${round(average(net_revenue),2)}'
        print(average_change)
        maxincrease_profits = f'The greatest increase in profits: ${net_revenue[0]}'
        greatestdecrease_profits = f'The greatest decrease in profits: ${net_revenue[len(net_revenue)-1]}'
        print(maxincrease_profits)
        print(greatestdecrease_profits)

# Solution to problem (run below section for Solution)
    
    
print("Financial Analysis")
print("______________________")
print(months)
print(net_profit)
print(average_change)
print(maxincrease_profits)
print(greatestdecrease_profits)
